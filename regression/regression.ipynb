# %%
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')

# %%
economy_df = pd.read_csv("C:/Users/wjddu/git/BIgData/EDA/Impact of Covid-19 Pandemic on the Global Economy.csv")

# %%
economy_df.rename(columns={"year": "년도",
                     "ISO_code": "ISO_CODE",
                     "countries": "나라",
                     "rank" :"순위",
                     "quartile": "사분위수",
                     "ECONOMIC FREEDOM": "경제적 자유도",
                     "1a_government_consumption": "정부 지출",
                     "1b_transfers": "전송",
                     "1c_gov_enterprises": "공기업",
                     "1d_top_marg_tax_rate": "최고 세율",
                     "1_size_government": "정부 규모",
                     "2a_judicial_independence": "사법권 독립도",
                     "2b_impartial_courts": "법원의 공평성", 
                     "2c_protection_property_rights": "재산권 보호 정도",
                     "2d_military_interference": "군사 개입도",
                     "2e_integrity_legal_system": "청렴한 법 체계성",
                     "2f_legal_enforcement_contracts": "법적 효력",
                     "2g_restrictions_sale_real_property": "부동산 매매 제한성",
                     "2h_reliability_police": "경찰 신뢰도",
                     "2i_business_costs_crime": "사업 범죄",
                     "2j_gender_adjustment": "성별 조정",
                     "2_property_rights": "재산권",
                     "3a_money_growth": "통화량",
                     "3b_std_inflation": "인플레이션 표준편차",
                     "3c_inflation": "인플레이션",
                     "3d_freedom_own_foreign_currency": "외화",
                     "3_sound_money": "건전한 돈",
                     "4a_tariffs": "관세",
                     "4b_regulatory_trade_barriers": "규제 무역 장비",
                     "4c_black_market": "암시장",
                     "4d_control_movement_capital_ppl": "이동 통제",
                     "4_trade": "거래",
                     "5a_credit_market_reg": "신용 시장 규제",
                     "5b_labor_market_reg": "노동 시장 규제",
                     "5c_business_reg": "사업 규제",
                     "5_regulation": "규정"}, inplace=True)

# %%
economy_df
# Out:
#         년도 ISO_CODE           나라  경제적 자유도     순위  사분위수     정부 지출        전송  \
# 0     2016      ALB      Albania     7.54   34.0   1.0  8.232353  7.509902
# 1     2016      DZA      Algeria     4.99  159.0   4.0  2.150000  7.817129
# 2     2016      AGO       Angola     5.17  155.0   4.0  7.600000  8.886739
# 3     2016      ARG    Argentina     4.84  160.0   4.0  5.335294  6.048930
# 4     2016      ARM      Armenia     7.57   29.0   1.0  7.264706  7.748532
# ...    ...      ...          ...      ...    ...   ...       ...       ...
# 3721  1970      VEN    Venezuela     7.18   10.0   1.0  6.602003  9.827430
# 3722  1970      VNM      Vietnam      NaN    NaN   NaN       NaN       NaN
# 3723  1970      YEM  Yemen, Rep.      NaN    NaN   NaN       NaN       NaN
# 3724  1970      ZMB       Zambia      NaN    NaN   NaN  3.448131  9.105430
# 3725  1970      ZWE     Zimbabwe      NaN    NaN   NaN  7.806922       NaN
#
# ...

# %%
economy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3726 entries, 0 to 3725
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년도          3726 non-null   int64
#  1   ISO_CODE    3726 non-null   object
#  2   나라          3726 non-null   object
#  3   경제적 자유도     3003 non-null   float64
#  4   순위          3003 non-null   float64
#  5   사분위수        3003 non-null   float64
#  6   정부 지출       3137 non-null   float64
#  7   전송          2766 non-null   float64
#  8   공기업         3080 non-null   float64
#  9   최고 세율       2679 non-null   float64
#  10  정부 규모       3079 non-null   float64
#  11  사법권 독립도     2173 non-null   float64
#  12  법원의 공평성     2547 non-null   float64
#  13  재산권 보호 정도   2597 non-null   float64
#  14  군사 개입도      2540 non-null   float64
#  15  청렴한 법 체계성   2573 non-null   float64
#  16  법적 효력       2365 non-null   float64
#  17  부동산 매매 제한성  2342 non-null   float64
# ...

# %%
economy_df.isnull().sum()
# Out:
# 년도               0
# ISO_CODE         0
# 나라               0
# 경제적 자유도        723
# 순위             723
# 사분위수           723
# 정부 지출          589
# 전송             960
# 공기업            646
# 최고 세율         1047
# 정부 규모          647
# 사법권 독립도       1553
# 법원의 공평성       1179
# 재산권 보호 정도     1129
# 군사 개입도        1186
# 청렴한 법 체계성     1153
# 법적 효력         1361
# 부동산 매매 제한성    1384
# 경찰 신뢰도        2071
# 사업 범죄         2071
# 성별 조정           66
# 재산권            755
# 통화량            644
# 인플레이션 표준편차     607
# 인플레이션          607
# 외화             621
# 건전한 돈          611
# 관세             681
# 규제 무역 장비      1348
# 암시장            617
# 이동 통제          592
# 거래             691
# 신용 시장 규제       619
# 노동 시장 규제      1158
# 사업 규제         1402
# 규정             728
# dtype: int64

# %%
economy_df.drop(columns='경찰 신뢰도', inplace=True)
economy_df.drop(columns='사업 범죄', inplace=True)

economy_df.head(5)
# Out:
#      년도 ISO_CODE         나라  경제적 자유도     순위  사분위수     정부 지출        전송  공기업  \
# 0  2016      ALB    Albania     7.54   34.0   1.0  8.232353  7.509902  8.0
# 1  2016      DZA    Algeria     4.99  159.0   4.0  2.150000  7.817129  0.0
# 2  2016      AGO     Angola     5.17  155.0   4.0  7.600000  8.886739  0.0
# 3  2016      ARG  Argentina     4.84  160.0   4.0  5.335294  6.048930  6.0
# 4  2016      ARM    Armenia     7.57   29.0   1.0  7.264706  7.748532  8.0
#
#    최고 세율  ...     건전한 돈        관세  규제 무역 장비       암시장     이동 통제        거래  \
# 0    8.0  ...  9.553657  8.963556  7.489905  10.00000  6.406138  8.214900
# 1    4.5  ...  7.253894  6.872533  2.481294   5.56391  1.590362  4.127025
# 2    9.5  ...  5.606605  6.989244  2.024949  10.00000  2.044823  5.264754
# 3    4.0  ...  5.614336  6.421600  4.811105   0.00000  4.697482  3.982547
# 4    5.0  ...  9.521940  8.547556  7.194410  10.00000  6.830998  8.143241
#
#    신용 시장 규제  노동 시장 규제     사업 규제        규정
# ...

# %%
economy_df.drop(columns='순위', inplace=True)
economy_df
# Out:
#         년도 ISO_CODE           나라  경제적 자유도  사분위수     정부 지출        전송  공기업  \
# 0     2016      ALB      Albania     7.54   1.0  8.232353  7.509902  8.0
# 1     2016      DZA      Algeria     4.99   4.0  2.150000  7.817129  0.0
# 2     2016      AGO       Angola     5.17   4.0  7.600000  8.886739  0.0
# 3     2016      ARG    Argentina     4.84   4.0  5.335294  6.048930  6.0
# 4     2016      ARM      Armenia     7.57   1.0  7.264706  7.748532  8.0
# ...    ...      ...          ...      ...   ...       ...       ...  ...
# 3721  1970      VEN    Venezuela     7.18   1.0  6.602003  9.827430  7.0
# 3722  1970      VNM      Vietnam      NaN   NaN       NaN       NaN  NaN
# 3723  1970      YEM  Yemen, Rep.      NaN   NaN       NaN       NaN  NaN
# 3724  1970      ZMB       Zambia      NaN   NaN  3.448131  9.105430  0.0
# 3725  1970      ZWE     Zimbabwe      NaN   NaN  7.806922       NaN  2.0
#
#       최고 세율     정부 규모  ...     건전한 돈        관세  규제 무역 장비       암시장     이동 통제  \
# ...

# %%
economy_df.drop(columns='ISO_CODE', inplace=True)
economy_df
# Out:
#         년도           나라  경제적 자유도  사분위수     정부 지출        전송  공기업  최고 세율  \
# 0     2016      Albania     7.54   1.0  8.232353  7.509902  8.0    8.0
# 1     2016      Algeria     4.99   4.0  2.150000  7.817129  0.0    4.5
# 2     2016       Angola     5.17   4.0  7.600000  8.886739  0.0    9.5
# 3     2016    Argentina     4.84   4.0  5.335294  6.048930  6.0    4.0
# 4     2016      Armenia     7.57   1.0  7.264706  7.748532  8.0    5.0
# ...    ...          ...      ...   ...       ...       ...  ...    ...
# 3721  1970    Venezuela     7.18   1.0  6.602003  9.827430  7.0    NaN
# 3722  1970      Vietnam      NaN   NaN       NaN       NaN  NaN    NaN
# 3723  1970  Yemen, Rep.      NaN   NaN       NaN       NaN  NaN    NaN
# 3724  1970       Zambia      NaN   NaN  3.448131  9.105430  0.0    NaN
# 3725  1970     Zimbabwe      NaN   NaN  7.806922       NaN  2.0    NaN
#
#          정부 규모   사법권 독립도  ...     건전한 돈        관세  규제 무역 장비       암시장  \
# ...

# %%
economy_df[economy_df.duplicated()]
economy_df
# Out:
#         년도           나라  경제적 자유도  사분위수     정부 지출        전송  공기업  최고 세율  \
# 0     2016      Albania     7.54   1.0  8.232353  7.509902  8.0    8.0
# 1     2016      Algeria     4.99   4.0  2.150000  7.817129  0.0    4.5
# 2     2016       Angola     5.17   4.0  7.600000  8.886739  0.0    9.5
# 3     2016    Argentina     4.84   4.0  5.335294  6.048930  6.0    4.0
# 4     2016      Armenia     7.57   1.0  7.264706  7.748532  8.0    5.0
# ...    ...          ...      ...   ...       ...       ...  ...    ...
# 3721  1970    Venezuela     7.18   1.0  6.602003  9.827430  7.0    NaN
# 3722  1970      Vietnam      NaN   NaN       NaN       NaN  NaN    NaN
# 3723  1970  Yemen, Rep.      NaN   NaN       NaN       NaN  NaN    NaN
# 3724  1970       Zambia      NaN   NaN  3.448131  9.105430  0.0    NaN
# 3725  1970     Zimbabwe      NaN   NaN  7.806922       NaN  2.0    NaN
#
#          정부 규모   사법권 독립도  ...     건전한 돈        관세  규제 무역 장비       암시장  \
# ...

# %%
economy_df.isnull().sum()
# Out:
# 년도               0
# 나라               0
# 경제적 자유도        723
# 사분위수           723
# 정부 지출          589
# 전송             960
# 공기업            646
# 최고 세율         1047
# 정부 규모          647
# 사법권 독립도       1553
# 법원의 공평성       1179
# 재산권 보호 정도     1129
# 군사 개입도        1186
# 청렴한 법 체계성     1153
# 법적 효력         1361
# 부동산 매매 제한성    1384
# 성별 조정           66
# 재산권            755
# 통화량            644
# 인플레이션 표준편차     607
# 인플레이션          607
# 외화             621
# 건전한 돈          611
# 관세             681
# 규제 무역 장비      1348
# 암시장            617
# 이동 통제          592
# 거래             691
# 신용 시장 규제       619
# 노동 시장 규제      1158
# 사업 규제         1402
# 규정             728
# dtype: int64

# %%
economy_df = economy_df.dropna(axis=0)
economy_df
# Out:
#         년도              나라  경제적 자유도  사분위수     정부 지출        전송   공기업  최고 세율  \
# 0     2016         Albania     7.54   1.0  8.232353  7.509902   8.0    8.0
# 1     2016         Algeria     4.99   4.0  2.150000  7.817129   0.0    4.5
# 2     2016          Angola     5.17   4.0  7.600000  8.886739   0.0    9.5
# 3     2016       Argentina     4.84   4.0  5.335294  6.048930   6.0    4.0
# 4     2016         Armenia     7.57   1.0  7.264706  7.748532   8.0    5.0
# ...    ...             ...      ...   ...       ...       ...   ...    ...
# 2744  2000         Ukraine     4.71   4.0  3.588235  6.256395   4.0    4.5
# 2746  2000  United Kingdom     8.56   1.0  5.952941  6.306993  10.0    5.0
# 2747  2000   United States     8.62   1.0  6.586778  6.541083   8.0    7.0
# 2749  2000       Venezuela     5.89   3.0  6.060960  7.740531   2.0    8.0
# 2753  2000        Zimbabwe     4.51   4.0  3.647059  7.746594  10.0    2.0
#
# ...

# %%
economy_df.isnull().sum()
# Out:
# 년도            0
# 나라            0
# 경제적 자유도       0
# 사분위수          0
# 정부 지출         0
# 전송            0
# 공기업           0
# 최고 세율         0
# 정부 규모         0
# 사법권 독립도       0
# 법원의 공평성       0
# 재산권 보호 정도     0
# 군사 개입도        0
# 청렴한 법 체계성     0
# 법적 효력         0
# 부동산 매매 제한성    0
# 성별 조정         0
# 재산권           0
# 통화량           0
# 인플레이션 표준편차    0
# 인플레이션         0
# 외화            0
# 건전한 돈         0
# 관세            0
# 규제 무역 장비      0
# 암시장           0
# 이동 통제         0
# 거래            0
# 신용 시장 규제      0
# 노동 시장 규제      0
# 사업 규제         0
# 규정            0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

economy_df[['경제적 자유도']] = scaler.fit_transform(economy_df[['경제적 자유도']])
economy_df[['사분위수']] = scaler.fit_transform(economy_df[['사분위수']])
economy_df[['정부 지출']] = scaler.fit_transform(economy_df[['정부 지출']])
economy_df[['전송']] = scaler.fit_transform(economy_df[['전송']])
economy_df[['공기업']] = scaler.fit_transform(economy_df[['공기업']])
economy_df[['최고 세율']] = scaler.fit_transform(economy_df[['최고 세율']])
economy_df[['정부 규모']] = scaler.fit_transform(economy_df[['정부 규모']])
economy_df[['사법권 독립도']] = scaler.fit_transform(economy_df[['사법권 독립도']])
economy_df[['법원의 공평성']] = scaler.fit_transform(economy_df[['법원의 공평성']])
economy_df[['재산권 보호 정도']] = scaler.fit_transform(economy_df[['재산권 보호 정도']])
economy_df[['군사 개입도']] = scaler.fit_transform(economy_df[['군사 개입도']])
economy_df[['청렴한 법 체계성']] = scaler.fit_transform(economy_df[['청렴한 법 체계성']])
economy_df[['법적 효력']] = scaler.fit_transform(economy_df[['법적 효력']])
economy_df[['부동산 매매 제한성']] = scaler.fit_transform(economy_df[['부동산 매매 제한성']])
economy_df[['성별 조정']] = scaler.fit_transform(economy_df[['성별 조정']])
economy_df[['재산권']] = scaler.fit_transform(economy_df[['재산권']])
economy_df[['통화량']] = scaler.fit_transform(economy_df[['통화량']])
economy_df[['인플레이션 표준편차']] = scaler.fit_transform(economy_df[['인플레이션 표준편차']])
economy_df[['인플레이션']] = scaler.fit_transform(economy_df[['인플레이션']])
economy_df[['외화']] = scaler.fit_transform(economy_df[['외화']])
economy_df[['건전한 돈']] = scaler.fit_transform(economy_df[['건전한 돈']])
economy_df[['관세']] = scaler.fit_transform(economy_df[['관세']])
economy_df[['규제 무역 장비']] = scaler.fit_transform(economy_df[['규제 무역 장비']])
economy_df[['암시장']] = scaler.fit_transform(economy_df[['암시장']])
economy_df[['이동 통제']] = scaler.fit_transform(economy_df[['이동 통제']])
economy_df[['거래']] = scaler.fit_transform(economy_df[['거래']])
economy_df[['신용 시장 규제']] = scaler.fit_transform(economy_df[['신용 시장 규제']])
economy_df[['노동 시장 규제']] = scaler.fit_transform(economy_df[['노동 시장 규제']])
economy_df[['사업 규제']] = scaler.fit_transform(economy_df[['사업 규제']])
economy_df[['규정']] = scaler.fit_transform(economy_df[['규정']])
economy_df.describe()
# Out:
#                 년도      경제적 자유도         사분위수        정부 지출           전송  \
# count  1701.000000  1701.000000  1701.000000  1701.000000  1701.000000
# mean   2008.866549     0.647902     0.414266     0.561875     0.665045
# std       4.711981     0.136662     0.357435     0.213260     0.269542
# min    2000.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2005.000000     0.562599     0.000000     0.429412     0.475646
# 50%    2009.000000     0.667195     0.333333     0.564706     0.720412
# 75%    2013.000000     0.736926     0.666667     0.726499     0.903660
# max    2016.000000     1.000000     1.000000     1.000000     1.000000
#
#                공기업        최고 세율        정부 규모      사법권 독립도      법원의 공평성  ...  \
# count  1701.000000  1701.000000  1701.000000  1701.000000  1701.000000  ...
# mean      0.695708     0.610288     0.528979     0.528687     0.491065  ...
# std       0.290171     0.227635     0.203172     0.236174     0.190409  ...
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
plt.rcParams['font.family'] = 'NanumGothic'

sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(economy_df.corr(), annot=True,)
# Out:
# <AxesSubplot:>

# %%
economy_df.rename(columns={"년도": "year",
                     "경제적 자유도": "Economic freedom",
                     "사분위수": "Quaternary",
                     "정부 지출": "Government spending",
                     "전송": "Transfer",
                     "공기업": "Publicly owned company",
                     "최고 세율": "Highest tax rate",
                     "정부 규모": "Size of government",
                     "사법권 독립도": "Independence of jurisdiction",
                     "법원의 공평성": "Court's fairness", 
                     "재산권 보호 정도": "Protection of property rights",
                     "군사 개입도": "Military intervention",
                     "청렴한 법 체계성": "Integrity legal system",
                     "법적 효력": "Legal effect",
                     "부동산 매매 제한성": "Restrictions on real estate sales",
                     "성별 조정": "Gender adjustment",
                     "재산권": "Property rights",
                     "통화량": "Money supply",
                     "인플레이션 표준편차": "Standard deviation of inflation",
                     "인플레이션": "Inflation",
                     "외화": "Foreign currency",
                     "건전한 돈": "Economic sound money",
                     "관세": "Tariff",
                     "규제 무역 장비": "Regulated trade equipment",
                     "암시장": "Black market",
                     "이동 통제": "Movement control",
                     "거래": "Trade",
                     "신용 시장 규제": "Credit market regulation",
                     "노동 시장 규제": "Labor market regulation",
                     "사업 규제": "Business regulation",
                     "규정": "Regulation"}, inplace=True)

# %%
economy_df
# Out:
#       year              나라  Economic freedom  Quaternary  Government spending  \
# 0     2016         Albania          0.738510    0.000000             0.823235
# 1     2016         Algeria          0.334390    1.000000             0.215000
# 2     2016          Angola          0.362916    1.000000             0.760000
# 3     2016       Argentina          0.310618    1.000000             0.533529
# 4     2016         Armenia          0.743265    0.000000             0.726471
# ...    ...             ...               ...         ...                  ...
# 2744  2000         Ukraine          0.290016    1.000000             0.358824
# 2746  2000  United Kingdom          0.900158    0.000000             0.595294
# 2747  2000   United States          0.909667    0.000000             0.658678
# 2749  2000       Venezuela          0.477021    0.666667             0.606096
# 2753  2000        Zimbabwe          0.258320    1.000000             0.364706
#
# ...

# %%
economy_df1 = economy_df.iloc[:,:15]

sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(economy_df1.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")

# %%
economy_df2 = economy_df.iloc[:,15:]

sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(economy_df2.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")

# %%
sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(economy_df.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")

# %%
import plotly.express as px

fig = px.scatter(economy_df, x="Economic freedom", y="Transfer", trendline="lowess")
fig.add_scatter(x = [0, 1], y = [0, 1], mode = 'lines+markers')
fig.show()

# %%
import plotly.express as px

fig = px.scatter(economy_df, x="Economic freedom", y="Property rights", trendline="lowess")
fig.add_scatter(x = [0, 1], y = [0, 1], mode = 'lines')
fig.show()

# %%
import plotly.express as px

fig = px.strip(economy_df, x = "Economic freedom", range_x=[0,1], color="year")
fig.show()

# %%
fig = px.line(economy_df, x="year", y="Foreign currency", range_x = [2000,2010])
fig.show()

# %%
import plotly.express as px

fig = px.histogram(economy_df, x="Foreign currency", range_x = [0,1])
fig.show()

# %%
import plotly.express as px

df = px.data.gapminder()

fig = px.scatter(economy_df, x="Economic freedom", y="Economic sound money")
fig.show()

# %%
import plotly.express as px

df = px.data.gapminder()

fig = px.scatter(economy_df, x="Economic freedom", y="Independence of jurisdiction",  size='Military intervention', log_x=True, )
fig.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks")

sns.lmplot(x="Integrity legal system", y="Military intervention", col="Quaternary", hue="Quaternary", data=economy_df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
import plotly.express as px

fig = px.scatter(economy_df, x="Economic freedom", y="Military intervention", size='Quaternary', color="year")
fig.show()

# %%
import plotly.express as px

fig = px.histogram(economy_df, x="Money supply")
fig.show()

# %%
import plotly.express as px

fig = px.density_heatmap(economy_df2, x="Foreign currency", y="Trade", marginal_x="histogram", marginal_y="histogram", text_auto=True)
fig.show()

# %%
import plotly.express as px

fig = px.scatter(economy_df, x="Integrity legal system", y="Military intervention", color="Quaternary", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %%
import plotly.express as px

fig = px.scatter_ternary(economy_df, a="Black market", b="Economic sound money", c="Foreign currency")
fig.show()

# %%
import plotly.express as px

fig = px.histogram(economy_df, x="Labor market regulation", color="Quaternary")
fig.show()

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Plot the responses for different events and regions
sns.lineplot(x="Labor market regulation", y="Highest tax rate",
             hue="Quaternary", style="Quaternary",
             data=economy_df)

# %%
import seaborn as sns
sns.set_theme(style="white")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="Money supply", y="Inflation", hue="Quaternary", size="Quaternary",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=economy_df)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

g = sns.jointplot(x="Money supply", y="Foreign currency", data=economy_df,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(data=economy_df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data_df = pd.DataFrame(np.random.rand(1000,3), columns = ['Inflation','Economic freedom','Economic sound money'])

sns.pairplot(data=data_df)
plt.show()

# %%
plt.scatter(x = 'Inflation', y = 'Economic freedom', data = economy_df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('Engine size vs C02 Emissions', fontsize = 16)
plt.ylabel('CO2 Emissions', fontsize = 12)
plt.xlabel('Engine Size', fontsize = 12)
plt.savefig('enginesize_co2.png')

# %%
plt.scatter(x = 'Inflation', y = 'Economic sound money', data = economy_df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('Inflation vs Economic sound money', fontsize = 16)
plt.ylabel('Economic sound money', fontsize = 12)
plt.xlabel('Inflation', fontsize = 12)
# Out:
# Text(0.5, 0, 'Inflation')

# %%
from sklearn.model_selection import train_test_split

X_var = economy_df[['Inflation']]
y_var = economy_df['Economic sound money']
X_train, X_test, y_train, y_test = train_test_split(X_var, y_var, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

# %%
from termcolor import colored as cl
print(cl('R-Squared :', attrs = ['bold']), lr.score(X_test, y_test))
# Out:
# R-Squared : 0.4928595409898672

# %%
slr_slope = lr.coef_
slr_intercept = lr.intercept_

sns.scatterplot(x = 'Inflation', y = 'Economic sound money', data = economy_df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.plot(economy_df['Inflation'], slr_slope*economy_df['Economic sound money'] + slr_intercept, color = 'r', linewidth = 1)

plt.title('Inflation vs Economic sound money', fontsize = 16)
plt.ylabel('Economic sound money', fontsize = 12)
plt.xlabel('Inflation', fontsize = 12)
plt.savefig('data.png')

# %%
from sklearn.model_selection import train_test_split
X1_var = economy_df[['Inflation', 'Economic sound money','Economic freedom']]
y_var = economy_df['Black market']

X_train, X_test, y_train, y_test = train_test_split(X1_var, y_var, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

# %%
from termcolor import colored as cl
print(cl('R-Squared :', attrs = ['bold']), 
lr.score(X_test, y_test))
# Out:
# R-Squared : 0.30496768076554537

# %%
sns.distplot(yhat, hist = False, color = 'r', label = 'Predicted Values')
sns.distplot(y_test, hist = False, color = 'b', label = 'Actual Values')

plt.title('Black mareket relation', fontsize = 16)
plt.xlabel('Values', fontsize = 12)
plt.ylabel('Black market', fontsize = 12)

plt.legend(loc = 'upper left', fontsize = 13)
plt.savefig('ap.png')
