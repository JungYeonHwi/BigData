# %%
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')

# %%
economy_df = pd.read_csv("C:/Users/wjddu/git/BIgData/EDA/Impact of Covid-19 Pandemic on the Global Economy.csv")

# %%
economy_df.rename(columns={"year": "년도",
                     "ISO_code": "ISO_CODE",
                     "countries": "나라",
                     "rank" :"순위",
                     "quartile": "사분위수",
                     "ECONOMIC FREEDOM": "경제적 자유도",
                     "1a_government_consumption": "정부 지출",
                     "1b_transfers": "전송",
                     "1c_gov_enterprises": "공기업",
                     "1d_top_marg_tax_rate": "최고 세율",
                     "1_size_government": "정부 규모",
                     "2a_judicial_independence": "사법권 독립도",
                     "2b_impartial_courts": "법원의 공평성", 
                     "2c_protection_property_rights": "재산권 보호 정도",
                     "2d_military_interference": "군사 개입도",
                     "2e_integrity_legal_system": "청렴한 법 체계성",
                     "2f_legal_enforcement_contracts": "법적 효력",
                     "2g_restrictions_sale_real_property": "부동산 매매 제한성",
                     "2h_reliability_police": "경찰 신뢰도",
                     "2i_business_costs_crime": "사업 범죄",
                     "2j_gender_adjustment": "성별 조정",
                     "2_property_rights": "재산권",
                     "3a_money_growth": "통화량",
                     "3b_std_inflation": "인플레이션 표준편차",
                     "3c_inflation": "인플레이션",
                     "3d_freedom_own_foreign_currency": "외화",
                     "3_sound_money": "건전한 돈",
                     "4a_tariffs": "관세",
                     "4b_regulatory_trade_barriers": "규제 무역 장비",
                     "4c_black_market": "암시장",
                     "4d_control_movement_capital_ppl": "이동 통제",
                     "4_trade": "거래",
                     "5a_credit_market_reg": "신용 시장 규제",
                     "5b_labor_market_reg": "노동 시장 규제",
                     "5c_business_reg": "사업 규제",
                     "5_regulation": "규정"}, inplace=True)

# %%
economy_df
# Out:
#         년도 ISO_CODE           나라  경제적 자유도     순위  사분위수     정부 지출        전송  \
# 0     2016      ALB      Albania     7.54   34.0   1.0  8.232353  7.509902
# 1     2016      DZA      Algeria     4.99  159.0   4.0  2.150000  7.817129
# 2     2016      AGO       Angola     5.17  155.0   4.0  7.600000  8.886739
# 3     2016      ARG    Argentina     4.84  160.0   4.0  5.335294  6.048930
# 4     2016      ARM      Armenia     7.57   29.0   1.0  7.264706  7.748532
# ...    ...      ...          ...      ...    ...   ...       ...       ...
# 3721  1970      VEN    Venezuela     7.18   10.0   1.0  6.602003  9.827430
# 3722  1970      VNM      Vietnam      NaN    NaN   NaN       NaN       NaN
# 3723  1970      YEM  Yemen, Rep.      NaN    NaN   NaN       NaN       NaN
# 3724  1970      ZMB       Zambia      NaN    NaN   NaN  3.448131  9.105430
# 3725  1970      ZWE     Zimbabwe      NaN    NaN   NaN  7.806922       NaN
#
#       공기업  최고 세율  ...     건전한 돈        관세  규제 무역 장비       암시장     이동 통제  \
# 0     8.0    8.0  ...  9.553657  8.963556  7.489905  10.00000  6.406138
# 1     0.0    4.5  ...  7.253894  6.872533  2.481294   5.56391  1.590362
# 2     0.0    9.5  ...  5.606605  6.989244  2.024949  10.00000  2.044823
# 3     6.0    4.0  ...  5.614336  6.421600  4.811105   0.00000  4.697482
# 4     8.0    5.0  ...  9.521940  8.547556  7.194410  10.00000  6.830998
# ...   ...    ...  ...       ...       ...       ...       ...       ...
# 3721  7.0    NaN  ...  9.713677  8.066667       NaN  10.00000  8.000000
# 3722  NaN    NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3723  NaN    NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3724  0.0    NaN  ...  5.133689       NaN       NaN   0.00000  2.000000
# 3725  2.0    NaN  ...  5.036667       NaN       NaN   7.20000       NaN
#
#             거래  신용 시장 규제  노동 시장 규제     사업 규제        규정
# 0     8.214900  7.098562  6.916278  6.705863  6.906901
# 1     4.127025  5.100509  5.029513  5.676956  5.268992
# 2     5.264754  7.064905  4.560325  4.930271  5.518500
# 3     3.982547  5.419820  5.151405  5.535831  5.369019
# 4     8.143241  9.102046  6.234630  6.797530  7.378069
# ...        ...       ...       ...       ...       ...
# 3721  8.688889  9.679680       NaN       NaN  5.312277
# 3722       NaN       NaN       NaN       NaN       NaN
# 3723       NaN       NaN       NaN       NaN       NaN
# 3724       NaN  7.327327       NaN       NaN       NaN
# 3725       NaN       NaN       NaN       NaN       NaN
#
# [3726 rows x 36 columns]

# %%
economy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3726 entries, 0 to 3725
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년도          3726 non-null   int64
#  1   ISO_CODE    3726 non-null   object
#  2   나라          3726 non-null   object
#  3   경제적 자유도     3003 non-null   float64
#  4   순위          3003 non-null   float64
#  5   사분위수        3003 non-null   float64
#  6   정부 지출       3137 non-null   float64
#  7   전송          2766 non-null   float64
#  8   공기업         3080 non-null   float64
#  9   최고 세율       2679 non-null   float64
#  10  정부 규모       3079 non-null   float64
#  11  사법권 독립도     2173 non-null   float64
#  12  법원의 공평성     2547 non-null   float64
#  13  재산권 보호 정도   2597 non-null   float64
#  14  군사 개입도      2540 non-null   float64
#  15  청렴한 법 체계성   2573 non-null   float64
#  16  법적 효력       2365 non-null   float64
#  17  부동산 매매 제한성  2342 non-null   float64
#  18  경찰 신뢰도      1655 non-null   float64
#  19  사업 범죄       1655 non-null   float64
#  20  성별 조정       3660 non-null   float64
#  21  재산권         2971 non-null   float64
#  22  통화량         3082 non-null   float64
#  23  인플레이션 표준편차  3119 non-null   float64
#  24  인플레이션       3119 non-null   float64
#  25  외화          3105 non-null   float64
#  26  건전한 돈       3115 non-null   float64
#  27  관세          3045 non-null   float64
#  28  규제 무역 장비    2378 non-null   float64
#  29  암시장         3109 non-null   float64
#  30  이동 통제       3134 non-null   float64
#  31  거래          3035 non-null   float64
#  32  신용 시장 규제    3107 non-null   float64
#  33  노동 시장 규제    2568 non-null   float64
#  34  사업 규제       2324 non-null   float64
#  35  규정          2998 non-null   float64
# dtypes: float64(33), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
economy_df.isnull().sum()
# Out:
# 년도               0
# ISO_CODE         0
# 나라               0
# 경제적 자유도        723
# 순위             723
# 사분위수           723
# 정부 지출          589
# 전송             960
# 공기업            646
# 최고 세율         1047
# 정부 규모          647
# 사법권 독립도       1553
# 법원의 공평성       1179
# 재산권 보호 정도     1129
# 군사 개입도        1186
# 청렴한 법 체계성     1153
# 법적 효력         1361
# 부동산 매매 제한성    1384
# 경찰 신뢰도        2071
# 사업 범죄         2071
# 성별 조정           66
# 재산권            755
# 통화량            644
# 인플레이션 표준편차     607
# 인플레이션          607
# 외화             621
# 건전한 돈          611
# 관세             681
# 규제 무역 장비      1348
# 암시장            617
# 이동 통제          592
# 거래             691
# 신용 시장 규제       619
# 노동 시장 규제      1158
# 사업 규제         1402
# 규정             728
# dtype: int64

# %%
economy_df.drop(columns='성별 조정', inplace=True)
economy_df.head(5)
# Out:
#      년도 ISO_CODE         나라  경제적 자유도     순위  사분위수     정부 지출        전송  공기업  \
# 0  2016      ALB    Albania     7.54   34.0   1.0  8.232353  7.509902  8.0
# 1  2016      DZA    Algeria     4.99  159.0   4.0  2.150000  7.817129  0.0
# 2  2016      AGO     Angola     5.17  155.0   4.0  7.600000  8.886739  0.0
# 3  2016      ARG  Argentina     4.84  160.0   4.0  5.335294  6.048930  6.0
# 4  2016      ARM    Armenia     7.57   29.0   1.0  7.264706  7.748532  8.0
#
#    최고 세율  ...     건전한 돈        관세  규제 무역 장비       암시장     이동 통제        거래  \
# 0    8.0  ...  9.553657  8.963556  7.489905  10.00000  6.406138  8.214900
# 1    4.5  ...  7.253894  6.872533  2.481294   5.56391  1.590362  4.127025
# 2    9.5  ...  5.606605  6.989244  2.024949  10.00000  2.044823  5.264754
# 3    4.0  ...  5.614336  6.421600  4.811105   0.00000  4.697482  3.982547
# 4    5.0  ...  9.521940  8.547556  7.194410  10.00000  6.830998  8.143241
#
#    신용 시장 규제  노동 시장 규제     사업 규제        규정
# 0  7.098562  6.916278  6.705863  6.906901
# 1  5.100509  5.029513  5.676956  5.268992
# 2  7.064905  4.560325  4.930271  5.518500
# 3  5.419820  5.151405  5.535831  5.369019
# 4  9.102046  6.234630  6.797530  7.378069
#
# [5 rows x 35 columns]

# %%
economy_df.drop_duplicates(inplace = True)

# %%
economy_df
# Out:
#         년도 ISO_CODE           나라  경제적 자유도     순위  사분위수     정부 지출        전송  \
# 0     2016      ALB      Albania     7.54   34.0   1.0  8.232353  7.509902
# 1     2016      DZA      Algeria     4.99  159.0   4.0  2.150000  7.817129
# 2     2016      AGO       Angola     5.17  155.0   4.0  7.600000  8.886739
# 3     2016      ARG    Argentina     4.84  160.0   4.0  5.335294  6.048930
# 4     2016      ARM      Armenia     7.57   29.0   1.0  7.264706  7.748532
# ...    ...      ...          ...      ...    ...   ...       ...       ...
# 3721  1970      VEN    Venezuela     7.18   10.0   1.0  6.602003  9.827430
# 3722  1970      VNM      Vietnam      NaN    NaN   NaN       NaN       NaN
# 3723  1970      YEM  Yemen, Rep.      NaN    NaN   NaN       NaN       NaN
# 3724  1970      ZMB       Zambia      NaN    NaN   NaN  3.448131  9.105430
# 3725  1970      ZWE     Zimbabwe      NaN    NaN   NaN  7.806922       NaN
#
#       공기업  최고 세율  ...     건전한 돈        관세  규제 무역 장비       암시장     이동 통제  \
# 0     8.0    8.0  ...  9.553657  8.963556  7.489905  10.00000  6.406138
# 1     0.0    4.5  ...  7.253894  6.872533  2.481294   5.56391  1.590362
# 2     0.0    9.5  ...  5.606605  6.989244  2.024949  10.00000  2.044823
# 3     6.0    4.0  ...  5.614336  6.421600  4.811105   0.00000  4.697482
# 4     8.0    5.0  ...  9.521940  8.547556  7.194410  10.00000  6.830998
# ...   ...    ...  ...       ...       ...       ...       ...       ...
# 3721  7.0    NaN  ...  9.713677  8.066667       NaN  10.00000  8.000000
# 3722  NaN    NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3723  NaN    NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3724  0.0    NaN  ...  5.133689       NaN       NaN   0.00000  2.000000
# 3725  2.0    NaN  ...  5.036667       NaN       NaN   7.20000       NaN
#
#             거래  신용 시장 규제  노동 시장 규제     사업 규제        규정
# 0     8.214900  7.098562  6.916278  6.705863  6.906901
# 1     4.127025  5.100509  5.029513  5.676956  5.268992
# 2     5.264754  7.064905  4.560325  4.930271  5.518500
# 3     3.982547  5.419820  5.151405  5.535831  5.369019
# 4     8.143241  9.102046  6.234630  6.797530  7.378069
# ...        ...       ...       ...       ...       ...
# 3721  8.688889  9.679680       NaN       NaN  5.312277
# 3722       NaN       NaN       NaN       NaN       NaN
# 3723       NaN       NaN       NaN       NaN       NaN
# 3724       NaN  7.327327       NaN       NaN       NaN
# 3725       NaN       NaN       NaN       NaN       NaN
#
# [3726 rows x 35 columns]

# %%
sns.heatmap(economy_df.isnull(), cbar=False)
# Out:
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49692 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47784 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54952 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52272 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47280 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49496 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49692 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47784 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54952 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52272 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47280 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49496 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjddu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
economy_df['경제적 자유도'].fillna(economy_df['경제적 자유도'].mean(), inplace=True)
economy_df.isnull().sum()
# Out:
# 년도               0
# ISO_CODE         0
# 나라               0
# 경제적 자유도          0
# 순위             723
# 사분위수           723
# 정부 지출          589
# 전송             960
# 공기업            646
# 최고 세율         1047
# 정부 규모          647
# 사법권 독립도       1553
# 법원의 공평성       1179
# 재산권 보호 정도     1129
# 군사 개입도        1186
# 청렴한 법 체계성     1153
# 법적 효력         1361
# 부동산 매매 제한성    1384
# 경찰 신뢰도        2071
# 사업 범죄         2071
# 재산권            755
# 통화량            644
# 인플레이션 표준편차     607
# 인플레이션          607
# 외화             621
# 건전한 돈          611
# 관세             681
# 규제 무역 장비      1348
# 암시장            617
# 이동 통제          592
# 거래             691
# 신용 시장 규제       619
# 노동 시장 규제      1158
# 사업 규제         1402
# 규정             728
# dtype: int64

# %%
economy_df['군사 개입도']
# Out:
# 0       8.333333
# 1       4.166667
# 2       3.333333
# 3       7.500000
# 4       5.833333
#           ...
# 3721    6.522995
# 3722    6.522995
# 3723    6.522995
# 3724    6.522995
# 3725    6.522995
# Name: 군사 개입도, Length: 3676, dtype: float64

# %%
economy_df['군사 개입도'].fillna(economy_df['군사 개입도'].mean(), inplace=True)
economy_df.isnull().sum()
# Out:
# 년도               0
# ISO_CODE         0
# 나라               0
# 경제적 자유도          0
# 순위             713
# 사분위수           713
# 정부 지출          586
# 전송             941
# 공기업            631
# 최고 세율         1026
# 정부 규모          640
# 사법권 독립도       1527
# 법원의 공평성       1156
# 재산권 보호 정도     1114
# 군사 개입도           0
# 청렴한 법 체계성     1133
# 법적 효력         1337
# 부동산 매매 제한성    1354
# 경찰 신뢰도        2041
# 사업 범죄         2041
# 재산권            746
# 통화량            637
# 인플레이션 표준편차     603
# 인플레이션          600
# 외화             618
# 건전한 돈          607
# 관세             667
# 규제 무역 장비      1325
# 암시장              0
# 이동 통제          589
# 거래             678
# 신용 시장 규제       616
# 노동 시장 규제      1136
# 사업 규제         1376
# 규정             726
# dtype: int64

# %%
economy_df['암시장']
# Out:
# 0          10.0
# 1       5.56391
# 2          10.0
# 3           0.0
# 4          10.0
#          ...
# 3721       10.0
# 3722        NaN
# 3723        NaN
# 3724        0.0
# 3725        7.2
# Name: 암시장, Length: 3726, dtype: object

# %%
economy_df.replace({'암시장': {10.0 : 'HIGH'}}, inplace = True)

# %%
economy_df['암시장']
# Out:
# 0          HIGH
# 1       5.56391
# 2          HIGH
# 3           0.0
# 4          HIGH
#          ...
# 3721       HIGH
# 3722        NaN
# 3723        NaN
# 3724        0.0
# 3725        7.2
# Name: 암시장, Length: 3726, dtype: object

# %%
sns.boxplot(y = economy_df['법적 효력'] );

# %%
economy_df.drop(economy_df[economy_df['법적 효력'] <= 0.0].index, inplace = True)
sns.boxplot(y = economy_df['법적 효력'] );

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
economy_df[['외화']] = scaler.fit_transform(economy_df[['외화']])
economy_df['외화']
# Out:
# 0       1.0
# 1       0.5
# 2       0.5
# 3       1.0
# 4       1.0
#        ...
# 3721    1.0
# 3722    NaN
# 3723    NaN
# 3724    0.0
# 3725    0.0
# Name: 외화, Length: 3676, dtype: float64

# %%
sns.heatmap(economy_df.corr(), annot=True,)
# Out:
# <AxesSubplot:>
