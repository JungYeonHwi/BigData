# %%
# 참고 블로그
# https://dschloe.github.io/python/python_edu/07_deeplearning/deep_learning_lstm/

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("C:/Users/wjddu/git/BigData/train/train_ori.csv")

# %%
dataframe
# Out:
#                 date  year  month  day  hour  pow_gen  month.1  hour.1  \
# 0      2016-12-13-14  2016     12   13    14  140.631       12      14
# 1      2016-12-13-15  2016     12   13    15   85.793       12      15
# 2      2016-12-13-16  2016     12   13    16   32.590       12      16
# 3      2016-12-13-17  2016     12   13    17    0.154       12      17
# 4      2016-12-13-18  2016     12   13    18    0.000       12      18
# ...              ...   ...    ...  ...   ...      ...      ...     ...
# 35482  2020-12-31-19  2020     12   31    19    0.000       12      19
# 35483  2020-12-31-20  2020     12   31    20    0.000       12      20
# 35484  2020-12-31-21  2020     12   31    21    0.000       12      21
# 35485  2020-12-31-22  2020     12   31    22    0.000       12      22
# 35486  2020-12-31-23  2020     12   31    23    0.000       12      23
#
#        temperature  humidity  dew_point  sol_rad  cloud
# 0              4.3        77        0.6  100.000      0
# 1              4.3        80        1.1   72.222      0
# 2              3.8        80        0.6   55.556      0
# 3              3.4        80        0.2   13.889      0
# 4              2.6        86        0.4    2.778      0
# ...            ...       ...        ...      ...    ...
# 35482         -0.9        65       -6.6    0.000      8
# 35483         -1.5        66       -7.0    0.000      8
# 35484         -1.9        75       -5.7    0.000      8
# 35485         -2.7        73       -6.8    0.000      8
# 35486         -4.0        84       -6.3    0.000      5
#
# [35487 rows x 13 columns]

# %%
dataframe = dataframe.loc[:, ~dataframe.T.duplicated()]
dataframe = dataframe.drop(['hour.1'], axis='columns')

# %%
dataframe
# Out:
#                 date  year  month  day  hour  pow_gen  temperature  humidity  \
# 0      2016-12-13-14  2016     12   13    14  140.631          4.3        77
# 1      2016-12-13-15  2016     12   13    15   85.793          4.3        80
# 2      2016-12-13-16  2016     12   13    16   32.590          3.8        80
# 3      2016-12-13-17  2016     12   13    17    0.154          3.4        80
# 4      2016-12-13-18  2016     12   13    18    0.000          2.6        86
# ...              ...   ...    ...  ...   ...      ...          ...       ...
# 35482  2020-12-31-19  2020     12   31    19    0.000         -0.9        65
# 35483  2020-12-31-20  2020     12   31    20    0.000         -1.5        66
# 35484  2020-12-31-21  2020     12   31    21    0.000         -1.9        75
# 35485  2020-12-31-22  2020     12   31    22    0.000         -2.7        73
# 35486  2020-12-31-23  2020     12   31    23    0.000         -4.0        84
#
#        dew_point  sol_rad  cloud
# 0            0.6  100.000      0
# 1            1.1   72.222      0
# 2            0.6   55.556      0
# 3            0.2   13.889      0
# 4            0.4    2.778      0
# ...          ...      ...    ...
# 35482       -6.6    0.000      8
# 35483       -7.0    0.000      8
# 35484       -5.7    0.000      8
# 35485       -6.8    0.000      8
# 35486       -6.3    0.000      5
#
# [35487 rows x 11 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35487 entries, 0 to 35486
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         35487 non-null  object
#  1   year         35487 non-null  int64
#  2   month        35487 non-null  int64
#  3   day          35487 non-null  int64
#  4   hour         35487 non-null  int64
#  5   pow_gen      35487 non-null  float64
#  6   temperature  35487 non-null  float64
#  7   humidity     35487 non-null  int64
#  8   dew_point    35487 non-null  float64
#  9   sol_rad      35487 non-null  float64
#  10  cloud        35487 non-null  int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 3.0+ MB

# %%
dataframe.isnull().sum()
# Out:
# date           0
# year           0
# month          0
# day            0
# hour           0
# pow_gen        0
# temperature    0
# humidity       0
# dew_point      0
# sol_rad        0
# cloud          0
# dtype: int64

# %%
dataframe.describe()
# Out:
#                year         month           day          hour       pow_gen  \
# count  35487.000000  35487.000000  35487.000000  35487.000000  35487.000000
# mean    2018.470679      6.590357     15.808747     11.500944    238.973340
# std        1.145249      3.481386      8.796943      6.924057    361.764514
# min     2016.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      4.000000      8.000000      5.000000      0.000000
# 50%     2018.000000      7.000000     16.000000     11.000000      0.170000
# 75%     2019.000000     10.000000     23.000000     18.000000    411.734500
# max     2020.000000     12.000000     31.000000     23.000000   1396.853000
#
#         temperature      humidity     dew_point       sol_rad         cloud
# count  35487.000000  35487.000000  35487.000000  35487.000000  35487.000000
# mean      13.678336     67.673711      6.832536    144.023715      3.040156
# std       10.079480     23.528315     11.879715    225.608522      3.948471
# min      -12.900000      0.000000    -26.900000      0.000000      0.000000
# 25%        5.300000     49.000000     -2.100000      0.000000      0.000000
# 50%       14.200000     71.000000      7.500000      2.778000      0.000000
# 75%       21.800000     89.000000     17.100000    230.556000      7.000000
# max       39.200000    100.000000     28.000000    975.000000     10.000000

# %%
sns.boxplot(y = dataframe['pow_gen'] );

# %%
quantile_25 = np.quantile(dataframe['pow_gen'], 0.25)
quantile_75 = np.quantile(dataframe['pow_gen'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -617.60175 1029.33625

# %%
dataframe.drop(dataframe[dataframe.pow_gen >= 1029.33625]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['temperature'] );

# %%
quantile_25 = np.quantile(dataframe['temperature'], 0.25)
quantile_75 = np.quantile(dataframe['temperature'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -19.450000000000003 45.75

# %%
dataframe.drop(dataframe[dataframe.temperature >= 45.75]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['humidity'] );

# %%
quantile_25 = np.quantile(dataframe['humidity'], 0.25)
quantile_75 = np.quantile(dataframe['humidity'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -7.5 148.5

# %%
dataframe.drop(dataframe[dataframe.humidity >= 148.5]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['dew_point'] );

# %%
quantile_25 = np.quantile(dataframe['dew_point'], 0.25)
quantile_75 = np.quantile(dataframe['dew_point'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -31.150000000000002 46.050000000000004

# %%
dataframe.drop(dataframe[dataframe.dew_point >= 46.050000000000004]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['sol_rad'] );

# %%
quantile_25 = np.quantile(dataframe['sol_rad'], 0.25)
quantile_75 = np.quantile(dataframe['sol_rad'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -266.667 444.44499999999994

# %%
dataframe.drop(dataframe[dataframe.dew_point >= 444.44499999999994]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['cloud'] );

# %%
quantile_25 = np.quantile(dataframe['cloud'], 0.25)
quantile_75 = np.quantile(dataframe['cloud'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -10.5 17.5

# %%
dataframe.drop(dataframe[dataframe.dew_point >= 17.5]. index, inplace = True)

# %%
#10시~15시는 pow_gen이 다른 시간대에 비하여 훨씬 높은 수치! 왜 그럴까? 
plt.figure(figsize=(16, 9))
sns.lineplot(y=dataframe['pow_gen'], x=dataframe['hour'])
plt.xlabel('hour')
plt.ylabel('pow_gen')
# Out:
# Text(0, 0.5, 'pow_gen')

# %%
dataframe.describe()
# Out:
#                year         month           day          hour       pow_gen  \
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean    2018.450358      6.366493     15.846789     11.385317    185.442600
# std        1.161391      3.942382      8.690990      7.121679    301.654632
# min     2016.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      3.000000      8.000000      5.000000      0.000000
# 50%     2018.000000      5.000000     16.000000     11.000000      0.000000
# 75%     2019.000000     10.000000     23.000000     18.000000    279.659000
# max     2020.000000     12.000000     31.000000     23.000000   1029.248000
#
#         temperature      humidity     dew_point       sol_rad         cloud
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean       9.623665     64.381051      2.179936    115.853330      2.652252
# std        8.400420     23.444417      9.769439    194.881219      3.802384
# min      -12.900000      0.000000    -26.900000      0.000000      0.000000
# 25%        3.000000     46.000000     -5.000000      0.000000      0.000000
# 50%        9.200000     65.000000      2.900000      0.000000      0.000000
# 75%       16.200000     85.000000     10.500000    169.444000      6.000000
# max       39.200000    100.000000     17.400000    955.556000     10.000000

# %%
from sklearn.preprocessing import MinMaxScaler

dataframe.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['pow_gen', 'temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']
df_scaled = scaler.fit_transform(dataframe[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

df_scaled
# Out:
#         pow_gen  temperature  humidity  dew_point   sol_rad  cloud
# 0      0.136635     0.330134      0.77   0.620767  0.104651    0.0
# 1      0.083355     0.330134      0.80   0.632054  0.075581    0.0
# 2      0.031664     0.320537      0.80   0.620767  0.058140    0.0
# 3      0.000150     0.312860      0.80   0.611738  0.014535    0.0
# 4      0.000000     0.297505      0.86   0.616253  0.002907    0.0
# ...         ...          ...       ...        ...       ...    ...
# 25548  0.000000     0.230326      0.65   0.458239  0.000000    0.8
# 25549  0.000000     0.218810      0.66   0.449210  0.000000    0.8
# 25550  0.000000     0.211132      0.75   0.478555  0.000000    0.8
# 25551  0.000000     0.195777      0.73   0.453725  0.000000    0.8
# 25552  0.000000     0.170825      0.84   0.465011  0.000000    0.5
#
# [25553 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

dataframe[['pow_gen']] = scaler.fit_transform(dataframe[['pow_gen']])
dataframe[['temperature']] = scaler.fit_transform(dataframe[['temperature']])
dataframe[['humidity']] = scaler.fit_transform(dataframe[['humidity']])
dataframe[['dew_point']] = scaler.fit_transform(dataframe[['dew_point']])
dataframe[['sol_rad']] = scaler.fit_transform(dataframe[['sol_rad']])
dataframe[['cloud']] = scaler.fit_transform(dataframe[['cloud']])

# %%
dataframe.describe()
# Out:
#                year         month           day          hour       pow_gen  \
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean    2018.450358      6.366493     15.846789     11.385317      0.180173
# std        1.161391      3.942382      8.690990      7.121679      0.293083
# min     2016.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      3.000000      8.000000      5.000000      0.000000
# 50%     2018.000000      5.000000     16.000000     11.000000      0.000000
# 75%     2019.000000     10.000000     23.000000     18.000000      0.271712
# max     2020.000000     12.000000     31.000000     23.000000      1.000000
#
#         temperature      humidity     dew_point       sol_rad         cloud
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean       0.432316      0.643811      0.656432      0.121242      0.265225
# std        0.161236      0.234444      0.220529      0.203945      0.380238
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.305182      0.460000      0.494357      0.000000      0.000000
# 50%        0.424184      0.650000      0.672686      0.000000      0.000000
# 75%        0.558541      0.850000      0.844244      0.177325      0.600000
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
dataframe
# Out:
#                 date  year  month  day  hour   pow_gen  temperature  humidity  \
# 0      2016-12-13-14  2016     12   13    14  0.136635     0.330134      0.77
# 1      2016-12-13-15  2016     12   13    15  0.083355     0.330134      0.80
# 2      2016-12-13-16  2016     12   13    16  0.031664     0.320537      0.80
# 3      2016-12-13-17  2016     12   13    17  0.000150     0.312860      0.80
# 4      2016-12-13-18  2016     12   13    18  0.000000     0.297505      0.86
# ...              ...   ...    ...  ...   ...       ...          ...       ...
# 35482  2020-12-31-19  2020     12   31    19  0.000000     0.230326      0.65
# 35483  2020-12-31-20  2020     12   31    20  0.000000     0.218810      0.66
# 35484  2020-12-31-21  2020     12   31    21  0.000000     0.211132      0.75
# 35485  2020-12-31-22  2020     12   31    22  0.000000     0.195777      0.73
# 35486  2020-12-31-23  2020     12   31    23  0.000000     0.170825      0.84
#
#        dew_point   sol_rad  cloud
# 0       0.620767  0.104651    0.0
# 1       0.632054  0.075581    0.0
# 2       0.620767  0.058140    0.0
# 3       0.611738  0.014535    0.0
# 4       0.616253  0.002907    0.0
# ...          ...       ...    ...
# 35482   0.458239  0.000000    0.8
# 35483   0.449210  0.000000    0.8
# 35484   0.478555  0.000000    0.8
# 35485   0.453725  0.000000    0.8
# 35486   0.465011  0.000000    0.5
#
# [25553 rows x 11 columns]

# %%
TEST_SIZE = 100
WINDOW_SIZE = 30

train = df_scaled[:-TEST_SIZE]
test = df_scaled[-TEST_SIZE:]

# %%
def make_dataset(data, label, window_size=30):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
from sklearn.model_selection import train_test_split

feature_cols = ['temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']
label_cols = ['pow_gen']

train_feature = train[feature_cols]
train_label = train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 30)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
x_train.shape, x_valid.shape
# Out:
# ((20338, 30, 5), (5085, 30, 5))

# %%
test_feature = test[feature_cols]
test_label = test[label_cols]

test_feature.shape, test_label.shape
# Out:
# ((100, 5), (100, 1))

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 30)
test_feature.shape, test_label.shape
# Out:
# ((70, 30, 5), (70, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(20, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )

model.add(Dense(1))

# %%
import os

model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)

model_path = 'model'
filename = os.path.join(model_path, 'tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                                    epochs=200, 
                                    batch_size=16,
                                    validation_data=(x_valid, y_valid), 
                                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0409
# Epoch 1: val_loss improved from inf to 0.02579, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 20s 14ms/step - loss: 0.0409 - val_loss: 0.0258
# Epoch 2/200
# 1269/1272 [============================>.] - ETA: 0s - loss: 0.0264
# Epoch 2: val_loss improved from 0.02579 to 0.02475, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0263 - val_loss: 0.0248
# Epoch 3/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0250
# Epoch 3: val_loss did not improve from 0.02475
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0250 - val_loss: 0.0259
# Epoch 4/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0240
# Epoch 4: val_loss improved from 0.02475 to 0.02308, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0240 - val_loss: 0.0231
# Epoch 5/200
# 1269/1272 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 5: val_loss improved from 0.02308 to 0.02144, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 18s 14ms/step - loss: 0.0234 - val_loss: 0.0214
# Epoch 6/200
# 1267/1272 [============================>.] - ETA: 0s - loss: 0.0228
# Epoch 6: val_loss did not improve from 0.02144
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0229 - val_loss: 0.0222
# Epoch 7/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0223
# Epoch 7: val_loss did not improve from 0.02144
# 1272/1272 [==============================] - 16s 13ms/step - loss: 0.0223 - val_loss: 0.0221
# Epoch 8/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0217
# Epoch 8: val_loss improved from 0.02144 to 0.02090, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 9/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0214
# Epoch 9: val_loss did not improve from 0.02090
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0214 - val_loss: 0.0209
# Epoch 10/200
# 1269/1272 [============================>.] - ETA: 0s - loss: 0.0209
# Epoch 10: val_loss improved from 0.02090 to 0.01990, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 18s 14ms/step - loss: 0.0210 - val_loss: 0.0199
# Epoch 11/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0208
# Epoch 11: val_loss improved from 0.01990 to 0.01961, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 19s 15ms/step - loss: 0.0208 - val_loss: 0.0196
# Epoch 12/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0202
# Epoch 12: val_loss did not improve from 0.01961
# 1272/1272 [==============================] - 19s 15ms/step - loss: 0.0202 - val_loss: 0.0200
# Epoch 13/200
# 1272/1272 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 13: val_loss did not improve from 0.01961
# 1272/1272 [==============================] - 19s 15ms/step - loss: 0.0200 - val_loss: 0.0198
# Epoch 14/200
# 1272/1272 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 14: val_loss improved from 0.01961 to 0.01907, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 19s 15ms/step - loss: 0.0196 - val_loss: 0.0191
# Epoch 15/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 15: val_loss improved from 0.01907 to 0.01827, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 20s 16ms/step - loss: 0.0193 - val_loss: 0.0183
# Epoch 16/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 16: val_loss improved from 0.01827 to 0.01785, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0192 - val_loss: 0.0178
# Epoch 17/200
# 1267/1272 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 17: val_loss did not improve from 0.01785
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0191 - val_loss: 0.0188
# Epoch 18/200
# 1272/1272 [==============================] - ETA: 0s - loss: 0.0188
# Epoch 18: val_loss improved from 0.01785 to 0.01752, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 14ms/step - loss: 0.0188 - val_loss: 0.0175
# Epoch 19/200
# 1269/1272 [============================>.] - ETA: 0s - loss: 0.0185
# Epoch 19: val_loss did not improve from 0.01752
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 20/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0182
# Epoch 20: val_loss improved from 0.01752 to 0.01696, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 18s 14ms/step - loss: 0.0182 - val_loss: 0.0170
# Epoch 21/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 21: val_loss did not improve from 0.01696
# 1272/1272 [==============================] - 19s 15ms/step - loss: 0.0181 - val_loss: 0.0174
# Epoch 22/200
# 1269/1272 [============================>.] - ETA: 0s - loss: 0.0179
# Epoch 22: val_loss did not improve from 0.01696
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 23/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 23: val_loss improved from 0.01696 to 0.01662, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 14ms/step - loss: 0.0177 - val_loss: 0.0166
# Epoch 24/200
# 1272/1272 [==============================] - ETA: 0s - loss: 0.0174
# Epoch 24: val_loss did not improve from 0.01662
# 1272/1272 [==============================] - 18s 14ms/step - loss: 0.0174 - val_loss: 0.0179
# Epoch 25/200
# 1269/1272 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 25: val_loss improved from 0.01662 to 0.01635, saving model to model\tmp_checkpoint.h5
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0174 - val_loss: 0.0163
# Epoch 26/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0173
# Epoch 26: val_loss did not improve from 0.01635
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0173 - val_loss: 0.0164
# Epoch 27/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 27: val_loss did not improve from 0.01635
# 1272/1272 [==============================] - 17s 13ms/step - loss: 0.0170 - val_loss: 0.0181
# Epoch 28/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 28: val_loss did not improve from 0.01635
# 1272/1272 [==============================] - 17s 14ms/step - loss: 0.0170 - val_loss: 0.0169
# Epoch 29/200
# 1271/1272 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 29: val_loss did not improve from 0.01635
# 1272/1272 [==============================] - 17s 14ms/step - loss: 0.0168 - val_loss: 0.0167
# Epoch 30/200
# 1270/1272 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 30: val_loss did not improve from 0.01635
# 1272/1272 [==============================] - 19s 15ms/step - loss: 0.0169 - val_loss: 0.0168

# %%
from sklearn.metrics import mean_squared_error

RMSE = mean_squared_error(test_label, pred)**0.5
print(RMSE)
# Out:
# 0.12913044207507227

# %%
#LSTM 모델 평가
ev=model.evaluate(test_feature,test_label, verbose=0)
print("손실 함수", ev[0], "MAE:",ev[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-92e391a132d4> in <module>
#       1 #LSTM 모델 평가
#       2 ev=model.evaluate(test_feature,test_label, verbose=0)
# ----> 3 print("손실 함수", ev[0], "MAE:",ev[1])
#
# TypeError: 'float' object is not subscriptable

# %%
#LSTM 모델로 예측 수행
pred=model.predict(x_test)
print("평균 절댓값 백분율 오차(MAPE)", sum(abs(test_label-pred)/test_label)/len(test_feature))

# %%
model.load_weights(filename)
pred = model.predict(test_feature)
pred.shape

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20)                2080
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 2,101
# Trainable params: 2,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd

X1_var = dataframe[['temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']]
y_var = dataframe['pow_gen'] # dependent variable
X_train, X_test, y_train, y_test = train_test_split(X1_var, y_var, test_size = 0.3, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-1000e182f880> in <module>
#       6 import pandas as pd
#       7
# ----> 8 X1_var = df[['temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']]
#       9 y_var = df['pow_gen'] # dependent variable
#      10 X_train, X_test, y_train, y_test = train_test_split(X1_var, y_var, test_size = 0.3, random_state = 0)
#
# NameError: name 'df' is not defined

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

# %%
from termcolor import colored as cl
print(cl('R-Squared :', attrs = ['bold']), 
lr.score(X_test, y_test))
# Out:
# R-Squared : 0.5347474444341092

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(y=dataframe['pow_gen'], x=dataframe['month'])
plt.xlabel('time')
plt.ylabel('pow_gen')
# Out:
# Text(0, 0.5, 'pow_gen')

# %%
stock_pow_gen=dataframe[['pow_gen']]
split_date = pd.Timestamp('2019-12-31')

#학습용 데이터와 테스트용 데이터로 분리
train_data=pd.DataFrame(stock_pow_gen.loc[:split_date,['Close']])
test_data=pd.DataFrame(stock_pow_gen.loc[split_date:,['Close']])

#분리된 데이터 시각화
ax = train_data.plot()
test_data.plot(ax=ax)
plt.legend(['train', 'test'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: Timestamp('2019-12-31 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5389         try:
# -> 5390             slc = self.get_loc(label)
#    5391         except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#
# KeyError: Timestamp('2019-12-31 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-4bcb9c86ed15> in <module>
#       3
#       4 #학습용 데이터와 테스트용 데이터로 분리
# ----> 5 train_data=pd.DataFrame(stock_pow_gen.loc[:split_date,['Close']])
#       6 test_data=pd.DataFrame(stock_pow_gen.loc[split_date:,['Close']])
#       7
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1100         if isinstance(key, slice):
#    1101             self._validate_key(key, axis)
# -> 1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
#    1104             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1134
#    1135         labels = obj._get_axis(axis)
# -> 1136         indexer = labels.slice_indexer(
#    1137             slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1138         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5275         slice(1, 3, None)
#    5276         """
# -> 5277         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5278
#    5279         # return a slice
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5480         end_slice = None
#    5481         if end is not None:
# -> 5482             end_slice = self.get_slice_bound(end, "right", kind)
#    5483         if end_slice is None:
#    5484             end_slice = len(self)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5391         except KeyError as err:
#    5392             try:
# -> 5393                 return self._searchsorted_monotonic(label, side)
#    5394             except ValueError:
#    5395                 # raise the original KeyError
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    5342     def _searchsorted_monotonic(self, label, side="left"):
#    5343         if self.is_monotonic_increasing:
# -> 5344             return self.searchsorted(label, side=side)
#    5345         elif self.is_monotonic_decreasing:
#    5346             # np.searchsorted expects ascending sort order, have to reverse
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in searchsorted(self, value, side, sorter)
#    1290     @doc(_shared_docs["searchsorted"], klass="Index")
#    1291     def searchsorted(self, value, side="left", sorter=None) -> np.ndarray:
# -> 1292         return algorithms.searchsorted(self._values, value, side=side, sorter=sorter)
#    1293
#    1294     def drop_duplicates(self, keep="first"):
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in searchsorted(arr, value, side, sorter)
#    1906             value = value.to_datetime64()
#    1907
# -> 1908     result = arr.searchsorted(value, side=side, sorter=sorter)
#    1909     return result
#    1910
#
# TypeError: '<' not supported between instances of 'int' and 'Timestamp'

# %%
#LSTM 모델에 맞게 데이터 셋 변형
x_train_t = x_train.reshape(x_train.shape[0], 30,1)
x_test_t = x_test.reshape(x_test.shape[0], 30, 1)

from keras.layers import LSTM 
from keras.models import Sequential 
from keras.layers import Dense 
import keras.backend as K 
from keras.callbacks import EarlyStopping 

K.clear_session() 
# Sequeatial Model
model = Sequential() 

# 첫번째 LSTM 레이어
model.add(LSTM(30,return_sequences=True, input_shape=(30, 1))) 
# 두번째 LSTM 레이어
model.add(LSTM(42,return_sequences=False))  

# 예측값 1개
model.add(Dense(1, activation='linear')) 
# 손실함수 지정 - 예측 값과 실제 값의 차이를 계산한다. MSE가 사용된다. 
# 최적화기 지정 - 일반적으로 adam을 사용한다.
model.compile(loss='mean_squared_error', optimizer='adam') 
model.summary()

# %%
sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(dataframe.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
dataframe2 = dataframe[['pow_gen', 'temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']]
dataframe2
# Out:
#         pow_gen  temperature  humidity  dew_point   sol_rad  cloud
# 0      0.136635     0.330134      0.77   0.620767  0.104651    0.0
# 1      0.083355     0.330134      0.80   0.632054  0.075581    0.0
# 2      0.031664     0.320537      0.80   0.620767  0.058140    0.0
# 3      0.000150     0.312860      0.80   0.611738  0.014535    0.0
# 4      0.000000     0.297505      0.86   0.616253  0.002907    0.0
# ...         ...          ...       ...        ...       ...    ...
# 35482  0.000000     0.230326      0.65   0.458239  0.000000    0.8
# 35483  0.000000     0.218810      0.66   0.449210  0.000000    0.8
# 35484  0.000000     0.211132      0.75   0.478555  0.000000    0.8
# 35485  0.000000     0.195777      0.73   0.453725  0.000000    0.8
# 35486  0.000000     0.170825      0.84   0.465011  0.000000    0.5
#
# [25553 rows x 6 columns]

# %%
sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(dataframe2.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
dataframe
# Out:
#                 date  year  month  day  hour   pow_gen  temperature  humidity  \
# 0      2016-12-13-14  2016     12   13    14  0.136635     0.330134      0.77
# 1      2016-12-13-15  2016     12   13    15  0.083355     0.330134      0.80
# 2      2016-12-13-16  2016     12   13    16  0.031664     0.320537      0.80
# 3      2016-12-13-17  2016     12   13    17  0.000150     0.312860      0.80
# 4      2016-12-13-18  2016     12   13    18  0.000000     0.297505      0.86
# ...              ...   ...    ...  ...   ...       ...          ...       ...
# 35482  2020-12-31-19  2020     12   31    19  0.000000     0.230326      0.65
# 35483  2020-12-31-20  2020     12   31    20  0.000000     0.218810      0.66
# 35484  2020-12-31-21  2020     12   31    21  0.000000     0.211132      0.75
# 35485  2020-12-31-22  2020     12   31    22  0.000000     0.195777      0.73
# 35486  2020-12-31-23  2020     12   31    23  0.000000     0.170825      0.84
#
#        dew_point   sol_rad  cloud
# 0       0.620767  0.104651    0.0
# 1       0.632054  0.075581    0.0
# 2       0.620767  0.058140    0.0
# 3       0.611738  0.014535    0.0
# 4       0.616253  0.002907    0.0
# ...          ...       ...    ...
# 35482   0.458239  0.000000    0.8
# 35483   0.449210  0.000000    0.8
# 35484   0.478555  0.000000    0.8
# 35485   0.453725  0.000000    0.8
# 35486   0.465011  0.000000    0.5
#
# [25553 rows x 11 columns]
