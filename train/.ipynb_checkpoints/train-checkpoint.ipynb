# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("C:/Users/wjddu/git/BigData/train/train_ori.csv")

# %%
dataframe
# Out:
#                 date  year  month  day  hour  pow_gen  month.1  hour.1  \
# 0      2016-12-13-14  2016     12   13    14  140.631       12      14
# 1      2016-12-13-15  2016     12   13    15   85.793       12      15
# 2      2016-12-13-16  2016     12   13    16   32.590       12      16
# 3      2016-12-13-17  2016     12   13    17    0.154       12      17
# 4      2016-12-13-18  2016     12   13    18    0.000       12      18
# ...              ...   ...    ...  ...   ...      ...      ...     ...
# 35482  2020-12-31-19  2020     12   31    19    0.000       12      19
# 35483  2020-12-31-20  2020     12   31    20    0.000       12      20
# 35484  2020-12-31-21  2020     12   31    21    0.000       12      21
# 35485  2020-12-31-22  2020     12   31    22    0.000       12      22
# 35486  2020-12-31-23  2020     12   31    23    0.000       12      23
#
#        temperature  humidity  dew_point  sol_rad  cloud
# 0              4.3        77        0.6  100.000      0
# 1              4.3        80        1.1   72.222      0
# 2              3.8        80        0.6   55.556      0
# 3              3.4        80        0.2   13.889      0
# 4              2.6        86        0.4    2.778      0
# ...            ...       ...        ...      ...    ...
# 35482         -0.9        65       -6.6    0.000      8
# 35483         -1.5        66       -7.0    0.000      8
# 35484         -1.9        75       -5.7    0.000      8
# 35485         -2.7        73       -6.8    0.000      8
# 35486         -4.0        84       -6.3    0.000      5
#
# [35487 rows x 13 columns]

# %%
dataframe = dataframe.loc[:, ~dataframe.T.duplicated()]
dataframe = dataframe.drop(['hour.1'], axis='columns')

# %%
dataframe
# Out:
#                 date  year  month  day  hour  pow_gen  temperature  humidity  \
# 0      2016-12-13-14  2016     12   13    14  140.631          4.3        77
# 1      2016-12-13-15  2016     12   13    15   85.793          4.3        80
# 2      2016-12-13-16  2016     12   13    16   32.590          3.8        80
# 3      2016-12-13-17  2016     12   13    17    0.154          3.4        80
# 4      2016-12-13-18  2016     12   13    18    0.000          2.6        86
# ...              ...   ...    ...  ...   ...      ...          ...       ...
# 35482  2020-12-31-19  2020     12   31    19    0.000         -0.9        65
# 35483  2020-12-31-20  2020     12   31    20    0.000         -1.5        66
# 35484  2020-12-31-21  2020     12   31    21    0.000         -1.9        75
# 35485  2020-12-31-22  2020     12   31    22    0.000         -2.7        73
# 35486  2020-12-31-23  2020     12   31    23    0.000         -4.0        84
#
#        dew_point  sol_rad  cloud
# 0            0.6  100.000      0
# 1            1.1   72.222      0
# 2            0.6   55.556      0
# 3            0.2   13.889      0
# 4            0.4    2.778      0
# ...          ...      ...    ...
# 35482       -6.6    0.000      8
# 35483       -7.0    0.000      8
# 35484       -5.7    0.000      8
# 35485       -6.8    0.000      8
# 35486       -6.3    0.000      5
#
# [35487 rows x 11 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35487 entries, 0 to 35486
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         35487 non-null  object
#  1   year         35487 non-null  int64
#  2   month        35487 non-null  int64
#  3   day          35487 non-null  int64
#  4   hour         35487 non-null  int64
#  5   pow_gen      35487 non-null  float64
#  6   temperature  35487 non-null  float64
#  7   humidity     35487 non-null  int64
#  8   dew_point    35487 non-null  float64
#  9   sol_rad      35487 non-null  float64
#  10  cloud        35487 non-null  int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 3.0+ MB

# %%
dataframe.isnull().sum()
# Out:
# date           0
# year           0
# month          0
# day            0
# hour           0
# pow_gen        0
# temperature    0
# humidity       0
# dew_point      0
# sol_rad        0
# cloud          0
# dtype: int64

# %%
dataframe.describe()
# Out:
#                year         month           day          hour       pow_gen  \
# count  35487.000000  35487.000000  35487.000000  35487.000000  35487.000000
# mean    2018.470679      6.590357     15.808747     11.500944    238.973340
# std        1.145249      3.481386      8.796943      6.924057    361.764514
# min     2016.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      4.000000      8.000000      5.000000      0.000000
# 50%     2018.000000      7.000000     16.000000     11.000000      0.170000
# 75%     2019.000000     10.000000     23.000000     18.000000    411.734500
# max     2020.000000     12.000000     31.000000     23.000000   1396.853000
#
#         temperature      humidity     dew_point       sol_rad         cloud
# count  35487.000000  35487.000000  35487.000000  35487.000000  35487.000000
# mean      13.678336     67.673711      6.832536    144.023715      3.040156
# std       10.079480     23.528315     11.879715    225.608522      3.948471
# min      -12.900000      0.000000    -26.900000      0.000000      0.000000
# 25%        5.300000     49.000000     -2.100000      0.000000      0.000000
# 50%       14.200000     71.000000      7.500000      2.778000      0.000000
# 75%       21.800000     89.000000     17.100000    230.556000      7.000000
# max       39.200000    100.000000     28.000000    975.000000     10.000000

# %%
sns.boxplot(y = dataframe['pow_gen'] );

# %%
quantile_25 = np.quantile(dataframe['pow_gen'], 0.25)
quantile_75 = np.quantile(dataframe['pow_gen'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -617.60175 1029.33625

# %%
dataframe.drop(dataframe[dataframe.pow_gen >= 1029.33625]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['temperature'] );

# %%
quantile_25 = np.quantile(dataframe['temperature'], 0.25)
quantile_75 = np.quantile(dataframe['temperature'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -19.450000000000003 45.75

# %%
dataframe.drop(dataframe[dataframe.temperature >= 45.75]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['humidity'] );

# %%
quantile_25 = np.quantile(dataframe['humidity'], 0.25)
quantile_75 = np.quantile(dataframe['humidity'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -7.5 148.5

# %%
dataframe.drop(dataframe[dataframe.humidity >= 148.5]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['dew_point'] );

# %%
quantile_25 = np.quantile(dataframe['dew_point'], 0.25)
quantile_75 = np.quantile(dataframe['dew_point'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -31.150000000000002 46.050000000000004

# %%
dataframe.drop(dataframe[dataframe.dew_point >= 46.050000000000004]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['sol_rad'] );

# %%
quantile_25 = np.quantile(dataframe['sol_rad'], 0.25)
quantile_75 = np.quantile(dataframe['sol_rad'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -266.667 444.44499999999994

# %%
dataframe.drop(dataframe[dataframe.dew_point >= 444.44499999999994]. index, inplace = True)

# %%
sns.boxplot(y = dataframe['cloud'] );

# %%
quantile_25 = np.quantile(dataframe['cloud'], 0.25)
quantile_75 = np.quantile(dataframe['cloud'],0.75)
IQR = quantile_75 - quantile_25
minimum = quantile_25 - 1.5 * IQR
maximum = quantile_75 + 1.5 * IQR
print(minimum, maximum)
# Out:
# -10.5 17.5

# %%
dataframe.drop(dataframe[dataframe.dew_point >= 17.5]. index, inplace = True)

# %%
#10시~15시는 pow_gen이 다른 시간대에 비하여 훨씬 높은 수치! 왜 그럴까? 
plt.figure(figsize=(16, 9))
sns.lineplot(y=dataframe['pow_gen'], x=dataframe['hour'])
plt.xlabel('time')
plt.ylabel('pow_gen')
# Out:
# Text(0, 0.5, 'pow_gen')

# %%
dataframe.describe()
# Out:
#                year         month           day          hour       pow_gen  \
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean    2018.450358      6.366493     15.846789     11.385317    185.442600
# std        1.161391      3.942382      8.690990      7.121679    301.654632
# min     2016.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      3.000000      8.000000      5.000000      0.000000
# 50%     2018.000000      5.000000     16.000000     11.000000      0.000000
# 75%     2019.000000     10.000000     23.000000     18.000000    279.659000
# max     2020.000000     12.000000     31.000000     23.000000   1029.248000
#
#         temperature      humidity     dew_point       sol_rad         cloud
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean       9.623665     64.381051      2.179936    115.853330      2.652252
# std        8.400420     23.444417      9.769439    194.881219      3.802384
# min      -12.900000      0.000000    -26.900000      0.000000      0.000000
# 25%        3.000000     46.000000     -5.000000      0.000000      0.000000
# 50%        9.200000     65.000000      2.900000      0.000000      0.000000
# 75%       16.200000     85.000000     10.500000    169.444000      6.000000
# max       39.200000    100.000000     17.400000    955.556000     10.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scale_cols = ['pow_gen', 'temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']
df_scaled = scaler.fit_transform(dataframe[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

df_scaled
# Out:
#         pow_gen  temperature  humidity  dew_point   sol_rad  cloud
# 0      0.136635     0.330134      0.77   0.620767  0.104651    0.0
# 1      0.083355     0.330134      0.80   0.632054  0.075581    0.0
# 2      0.031664     0.320537      0.80   0.620767  0.058140    0.0
# 3      0.000150     0.312860      0.80   0.611738  0.014535    0.0
# 4      0.000000     0.297505      0.86   0.616253  0.002907    0.0
# ...         ...          ...       ...        ...       ...    ...
# 25548  0.000000     0.230326      0.65   0.458239  0.000000    0.8
# 25549  0.000000     0.218810      0.66   0.449210  0.000000    0.8
# 25550  0.000000     0.211132      0.75   0.478555  0.000000    0.8
# 25551  0.000000     0.195777      0.73   0.453725  0.000000    0.8
# 25552  0.000000     0.170825      0.84   0.465011  0.000000    0.5
#
# [25553 rows x 6 columns]

# %%
dataframe.describe()
# Out:
#                year         month           day          hour       pow_gen  \
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean    2018.450358      6.366493     15.846789     11.385317      0.180173
# std        1.161391      3.942382      8.690990      7.121679      0.293083
# min     2016.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      3.000000      8.000000      5.000000      0.000000
# 50%     2018.000000      5.000000     16.000000     11.000000      0.000000
# 75%     2019.000000     10.000000     23.000000     18.000000      0.271712
# max     2020.000000     12.000000     31.000000     23.000000      1.000000
#
#         temperature      humidity     dew_point       sol_rad         cloud
# count  25553.000000  25553.000000  25553.000000  25553.000000  25553.000000
# mean       0.432316      0.643811      0.656432      0.121242      0.265225
# std        0.161236      0.234444      0.220529      0.203945      0.380238
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.305182      0.460000      0.494357      0.000000      0.000000
# 50%        0.424184      0.650000      0.672686      0.000000      0.000000
# 75%        0.558541      0.850000      0.844244      0.177325      0.600000
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
TEST_SIZE = 200
WINDOW_SIZE = 30

train = df_scaled[:-TEST_SIZE]
test = df_scaled[-TEST_SIZE:]

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
from sklearn.model_selection import train_test_split

feature_cols = ['temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']
label_cols = ['pow_gen']

train_feature = train[feature_cols]
train_label = train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 20)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
x_train.shape, x_valid.shape
# Out:
# ((19626, 20, 5), (4907, 20, 5))

# %%
test_feature = test[feature_cols]
test_label = test[label_cols]

test_feature.shape, test_label.shape
# Out:
# ((1000, 5), (1000, 1))

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 20)
test_feature.shape, test_label.shape
# Out:
# ((980, 20, 5), (980, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )

model.add(Dense(1))

# %%
import os

model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)

model_path = 'model'
filename = os.path.join(model_path, 'tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                                    epochs=200, 
                                    batch_size=16,
                                    validation_data=(x_valid, y_valid), 
                                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 1225/1227 [============================>.] - ETA: 0s - loss: 0.0447
# Epoch 1: val_loss improved from inf to 0.03123, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 10s 7ms/step - loss: 0.0447 - val_loss: 0.0312
# Epoch 2/200
# 1222/1227 [============================>.] - ETA: 0s - loss: 0.0315
# Epoch 2: val_loss did not improve from 0.03123
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0314 - val_loss: 0.0318
# Epoch 3/200
# 1222/1227 [============================>.] - ETA: 0s - loss: 0.0291
# Epoch 3: val_loss improved from 0.03123 to 0.02689, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0291 - val_loss: 0.0269
# Epoch 4/200
# 1225/1227 [============================>.] - ETA: 0s - loss: 0.0278
# Epoch 4: val_loss improved from 0.02689 to 0.02493, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0278 - val_loss: 0.0249
# Epoch 5/200
# 1227/1227 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 5: val_loss did not improve from 0.02493
# 1227/1227 [==============================] - 11s 9ms/step - loss: 0.0273 - val_loss: 0.0254
# Epoch 6/200
# 1225/1227 [============================>.] - ETA: 0s - loss: 0.0272
# Epoch 6: val_loss improved from 0.02493 to 0.02484, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 12s 10ms/step - loss: 0.0272 - val_loss: 0.0248
# Epoch 7/200
# 1224/1227 [============================>.] - ETA: 0s - loss: 0.0265
# Epoch 7: val_loss improved from 0.02484 to 0.02382, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 12s 10ms/step - loss: 0.0265 - val_loss: 0.0238
# Epoch 8/200
# 1221/1227 [============================>.] - ETA: 0s - loss: 0.0257
# Epoch 8: val_loss improved from 0.02382 to 0.02364, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 11s 9ms/step - loss: 0.0258 - val_loss: 0.0236
# Epoch 9/200
# 1221/1227 [============================>.] - ETA: 0s - loss: 0.0257
# Epoch 9: val_loss did not improve from 0.02364
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0257 - val_loss: 0.0237
# Epoch 10/200
# 1224/1227 [============================>.] - ETA: 0s - loss: 0.0249
# Epoch 10: val_loss improved from 0.02364 to 0.02263, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0250 - val_loss: 0.0226
# Epoch 11/200
# 1227/1227 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 11: val_loss improved from 0.02263 to 0.02243, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 9s 8ms/step - loss: 0.0245 - val_loss: 0.0224
# Epoch 12/200
# 1220/1227 [============================>.] - ETA: 0s - loss: 0.0244
# Epoch 12: val_loss did not improve from 0.02243
# 1227/1227 [==============================] - 9s 8ms/step - loss: 0.0244 - val_loss: 0.0226
# Epoch 13/200
# 1224/1227 [============================>.] - ETA: 0s - loss: 0.0239
# Epoch 13: val_loss improved from 0.02243 to 0.02222, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 9s 8ms/step - loss: 0.0239 - val_loss: 0.0222
# Epoch 14/200
# 1222/1227 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 14: val_loss did not improve from 0.02222
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0234 - val_loss: 0.0228
# Epoch 15/200
# 1221/1227 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 15: val_loss improved from 0.02222 to 0.02206, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0234 - val_loss: 0.0221
# Epoch 16/200
# 1221/1227 [============================>.] - ETA: 0s - loss: 0.0230
# Epoch 16: val_loss did not improve from 0.02206
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0230 - val_loss: 0.0222
# Epoch 17/200
# 1225/1227 [============================>.] - ETA: 0s - loss: 0.0227
# Epoch 17: val_loss did not improve from 0.02206
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0227 - val_loss: 0.0226
# Epoch 18/200
# 1221/1227 [============================>.] - ETA: 0s - loss: 0.0224
# Epoch 18: val_loss improved from 0.02206 to 0.02187, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0224 - val_loss: 0.0219
# Epoch 19/200
# 1220/1227 [============================>.] - ETA: 0s - loss: 0.0222
# Epoch 19: val_loss improved from 0.02187 to 0.02150, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0222 - val_loss: 0.0215
# Epoch 20/200
# 1223/1227 [============================>.] - ETA: 0s - loss: 0.0219
# Epoch 20: val_loss did not improve from 0.02150
# 1227/1227 [==============================] - 9s 8ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 21/200
# 1224/1227 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 21: val_loss did not improve from 0.02150
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0218 - val_loss: 0.0217
# Epoch 22/200
# 1220/1227 [============================>.] - ETA: 0s - loss: 0.0214
# Epoch 22: val_loss improved from 0.02150 to 0.02050, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] -
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0177 - val_loss: 0.0182
# Epoch 55/200
# 1222/1227 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 55: val_loss did not improve from 0.01736
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0175 - val_loss: 0.0177
# Epoch 56/200
# 1223/1227 [============================>.] - ETA: 0s - loss: 0.0176
# Epoch 56: val_loss improved from 0.01736 to 0.01720, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 10s 8ms/step - loss: 0.0176 - val_loss: 0.0172
# Epoch 57/200
# 1220/1227 [============================>.] - ETA: 0s - loss: 0.0176
# Epoch 57: val_loss improved from 0.01720 to 0.01688, saving model to model\tmp_checkpoint.h5
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0176 - val_loss: 0.0169
# Epoch 58/200
# 1224/1227 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 58: val_loss did not improve from 0.01688
# 1227/1227 [==============================] - 12s 10ms/step - loss: 0.0175 - val_loss: 0.0173
# Epoch 59/200
# 1222/1227 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 59: val_loss did not improve from 0.01688
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0175 - val_loss: 0.0177
# Epoch 60/200
# 1224/1227 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 60: val_loss did not improve from 0.01688
# 1227/1227 [==============================] - 9s 7ms/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 61/200
# 1226/1227 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 61: val_loss did not improve from 0.01688
# 1227/1227 [==============================] - 13s 11ms/step - loss: 0.0174 - val_loss: 0.0173
# Epoch 62/200
# 1223/1227 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 62: val_loss did not improve from 0.01688
# 1227/1227 [==============================] - 14s 11ms/step - loss: 0.0174 - val_loss: 0.0170

# %%
model.load_weights(filename)
pred = model.predict(test_feature)

pred.shape
# Out:
# (980, 1)

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
print("정확도 : %4.f" %(model.evaluate(test_label, pred)))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 20, 5) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20, 5), dtype=tf.float32, name='lstm_1_input'), name='lstm_1_input', description="created by layer 'lstm_1_input'"), but it was called on an input with incompatible shape (None, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-cf27c816fdd0> in <module>
# ----> 1 print("정확도 : %4.f" %(model.evaluate(test_label, pred)))
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "C:\Users\wjddu\anaconda3\lib\site-packages\keras\engine\training.py", line 1525, in test_function  *
#         return step_function(self, iterator)
#     File "C:\Users\wjddu\anaconda3\lib\site-packages\keras\engine\training.py", line 1514, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\wjddu\anaconda3\lib\site-packages\keras\engine\training.py", line 1507, in run_step  **
#         outputs = model.test_step(data)
#     File "C:\Users\wjddu\anaconda3\lib\site-packages\keras\engine\training.py", line 1471, in test_step
#         y_pred = self(x, training=False)
#     File "C:\Users\wjddu\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\wjddu\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 214, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#     ValueError: Exception encountered when calling layer "sequential_1" (type Sequential).
#
#     Input 0 of layer "lstm_1" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 1)
#
#     Call arguments received:
#       • inputs=tf.Tensor(shape=(None, 1), dtype=float32)
#       • training=False
#       • mask=None

# %%
sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(dataframe.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
dataframe2 = dataframe[['pow_gen', 'temperature', 'humidity', 'dew_point', 'sol_rad', 'cloud']]
dataframe2
# Out:
#         pow_gen  temperature  humidity  dew_point   sol_rad  cloud
# 0      0.136635     0.330134      0.77   0.620767  0.104651    0.0
# 1      0.083355     0.330134      0.80   0.632054  0.075581    0.0
# 2      0.031664     0.320537      0.80   0.620767  0.058140    0.0
# 3      0.000150     0.312860      0.80   0.611738  0.014535    0.0
# 4      0.000000     0.297505      0.86   0.616253  0.002907    0.0
# ...         ...          ...       ...        ...       ...    ...
# 35482  0.000000     0.230326      0.65   0.458239  0.000000    0.8
# 35483  0.000000     0.218810      0.66   0.449210  0.000000    0.8
# 35484  0.000000     0.211132      0.75   0.478555  0.000000    0.8
# 35485  0.000000     0.195777      0.73   0.453725  0.000000    0.8
# 35486  0.000000     0.170825      0.84   0.465011  0.000000    0.5
#
# [25553 rows x 6 columns]

# %%
sns.set(rc = {'figure.figsize':(15,8)})

sns.heatmap(dataframe2.corr(), annot=True, linewidths=0.5, fmt=".2f", cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
dataframe
# Out:
#                 date  year  month  day  hour   pow_gen  temperature  humidity  \
# 0      2016-12-13-14  2016     12   13    14  0.136635     0.330134      0.77
# 1      2016-12-13-15  2016     12   13    15  0.083355     0.330134      0.80
# 2      2016-12-13-16  2016     12   13    16  0.031664     0.320537      0.80
# 3      2016-12-13-17  2016     12   13    17  0.000150     0.312860      0.80
# 4      2016-12-13-18  2016     12   13    18  0.000000     0.297505      0.86
# ...              ...   ...    ...  ...   ...       ...          ...       ...
# 35482  2020-12-31-19  2020     12   31    19  0.000000     0.230326      0.65
# 35483  2020-12-31-20  2020     12   31    20  0.000000     0.218810      0.66
# 35484  2020-12-31-21  2020     12   31    21  0.000000     0.211132      0.75
# 35485  2020-12-31-22  2020     12   31    22  0.000000     0.195777      0.73
# 35486  2020-12-31-23  2020     12   31    23  0.000000     0.170825      0.84
#
#        dew_point   sol_rad  cloud
# 0       0.620767  0.104651    0.0
# 1       0.632054  0.075581    0.0
# 2       0.620767  0.058140    0.0
# 3       0.611738  0.014535    0.0
# 4       0.616253  0.002907    0.0
# ...          ...       ...    ...
# 35482   0.458239  0.000000    0.8
# 35483   0.449210  0.000000    0.8
# 35484   0.478555  0.000000    0.8
# 35485   0.453725  0.000000    0.8
# 35486   0.465011  0.000000    0.5
#
# [25553 rows x 11 columns]
