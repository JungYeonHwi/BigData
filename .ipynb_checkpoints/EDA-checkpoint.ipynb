# %%
import pandas as pd

# %%
economy_df = pd.read_csv("C:/Users/wjddu/git/BIgData/EDA/Impact of Covid-19 Pandemic on the Global Economy.csv")

# %%
economy_df.rename(columns={"year": "년도",
                     "ISO_code": "ISO_CODE",
                     "countries": "나라",
                     "rank" :"순위",
                     "quartile": "사분위수",
                     "ECONOMIC FREEDOM": "경제적 자유도",
                     "1a_government_consumption": "정부 지출",
                     "1b_transfers": "전송",
                     "1c_gov_enterprises": "공기업",
                     "1d_top_marg_tax_rate": "최고 세율",
                     "1_size_government": "정부 규모",
                     "2a_judicial_independence": "사법권 독립도",
                     "2b_impartial_courts": "법원의 공평성", 
                     "2c_protection_property_rights": "재산권 보호 정도",
                     "2d_military_interference": "군사 개입도",
                     "2e_integrity_legal_system": "청렴한 법 체계성",
                     "2f_legal_enforcement_contracts": "법적 효력",
                     "2g_restrictions_sale_real_property": "부동산 매매 제한성",
                     "2h_reliability_police": "경찰 신뢰도",
                     "2i_business_costs_crime": "사업 범죄",
                     "2j_gender_adjustment": "성별 조정",
                     "2_property_rights": "재산권",
                     "3a_money_growth": "통화량",
                     "3b_std_inflation": "인플레이션 표준편차",
                     "3c_inflation": "인플레이션",
                     "3d_freedom_own_foreign_currency": "외화",
                     "3_sound_money": "건전한 돈",
                     "4a_tariffs": "관세",
                     "4c_black_market": "암시장",
                     "4d_control_movement_capital_ppl": "이동 통제",
                     "4_trade": "거래",
                     "5a_credit_market_reg": "신용 시장 규제",
                     "5b_labor_market_reg": "노동 시장 규제",
                     "5_regulation": "규정"}, inplace=True)

# %%
economy_df
# Out:
#         년도 ISO_CODE           나라  경제적 자유도     순위  사분위수     정부 지출        전송  \
# 0     2016      ALB      Albania     7.54   34.0   1.0  8.232353  7.509902
# 1     2016      DZA      Algeria     4.99  159.0   4.0  2.150000  7.817129
# 2     2016      AGO       Angola     5.17  155.0   4.0  7.600000  8.886739
# 3     2016      ARG    Argentina     4.84  160.0   4.0  5.335294  6.048930
# 4     2016      ARM      Armenia     7.57   29.0   1.0  7.264706  7.748532
# ...    ...      ...          ...      ...    ...   ...       ...       ...
# 3721  1970      VEN    Venezuela     7.18   10.0   1.0  6.602003  9.827430
# 3722  1970      VNM      Vietnam      NaN    NaN   NaN       NaN       NaN
# 3723  1970      YEM  Yemen, Rep.      NaN    NaN   NaN       NaN       NaN
# 3724  1970      ZMB       Zambia      NaN    NaN   NaN  3.448131  9.105430
# 3725  1970      ZWE     Zimbabwe      NaN    NaN   NaN  7.806922       NaN
#
#       공기업  최고 세율  ...  SOUND_MONEY   TARIFFS  4b_regulatory_trade_barriers  \
# 0     8.0    8.0  ...     9.553657  8.963556                      7.489905
# 1     0.0    4.5  ...     7.253894  6.872533                      2.481294
# 2     0.0    9.5  ...     5.606605  6.989244                      2.024949
# 3     6.0    4.0  ...     5.614336  6.421600                      4.811105
# 4     8.0    5.0  ...     9.521940  8.547556                      7.194410
# ...   ...    ...  ...          ...       ...                           ...
# 3721  7.0    NaN  ...     9.713677  8.066667                           NaN
# 3722  NaN    NaN  ...          NaN       NaN                           NaN
# 3723  NaN    NaN  ...          NaN       NaN                           NaN
# 3724  0.0    NaN  ...     5.133689       NaN                           NaN
# 3725  2.0    NaN  ...     5.036667       NaN                           NaN
#
#       BLACK_MARKET  CONTROL_MOVEMENT     TRADE  CREDIT_MARKET_REG  \
# 0         10.00000          6.406138  8.214900           7.098562
# 1          5.56391          1.590362  4.127025           5.100509
# 2         10.00000          2.044823  5.264754           7.064905
# 3          0.00000          4.697482  3.982547           5.419820
# 4         10.00000          6.830998  8.143241           9.102046
# ...            ...               ...       ...                ...
# 3721      10.00000          8.000000  8.688889           9.679680
# 3722           NaN               NaN       NaN                NaN
# 3723           NaN               NaN       NaN                NaN
# 3724       0.00000          2.000000       NaN           7.327327
# 3725       7.20000               NaN       NaN                NaN
#
#       LABOR_MARKET_REG  5c_business_reg  REGULATION
# 0             6.916278         6.705863    6.906901
# 1             5.029513         5.676956    5.268992
# 2             4.560325         4.930271    5.518500
# 3             5.151405         5.535831    5.369019
# 4             6.234630         6.797530    7.378069
# ...                ...              ...         ...
# 3721               NaN              NaN    5.312277
# 3722               NaN              NaN         NaN
# 3723               NaN              NaN         NaN
# 3724               NaN              NaN         NaN
# 3725               NaN              NaN         NaN
#
# [3726 rows x 36 columns]

# %%
economy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3726 entries, 0 to 3725
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   년도                            3726 non-null   int64
#  1   ISO_CODE                      3726 non-null   object
#  2   나라                            3726 non-null   object
#  3   경제적 자유도                       3003 non-null   float64
#  4   순위                            3003 non-null   float64
#  5   사분위수                          3003 non-null   float64
#  6   정부 지출                         3137 non-null   float64
#  7   전송                            2766 non-null   float64
#  8   공기업                           3080 non-null   float64
#  9   최고 세율                         2679 non-null   float64
#  10  정부 규모                         3079 non-null   float64
#  11  사법권 독립도                       2173 non-null   float64
#  12  법원의 공평성                       2547 non-null   float64
#  13  재산권 보호 정도                     2597 non-null   float64
#  14  군사 개입도                        2540 non-null   float64
#  15  청렴한 법 체계성                     2573 non-null   float64
#  16  법적 효력                         2365 non-null   float64
#  17  부동산 매매 제한성                    2342 non-null   float64
#  18  경찰 신뢰도                        1655 non-null   float64
#  19  사업 범죄                         1655 non-null   float64
#  20  GENDER_ADJUSTMENT             3660 non-null   float64
#  21  PROPERTY_RIGHTS               2971 non-null   float64
#  22  MONEY_GROWTH                  3082 non-null   float64
#  23  STD_INFLATION                 3119 non-null   float64
#  24  INFLATION                     3119 non-null   float64
#  25  FOREIGN_CURRENCY              3105 non-null   float64
#  26  SOUND_MONEY                   3115 non-null   float64
#  27  TARIFFS                       3045 non-null   float64
#  28  4b_regulatory_trade_barriers  2378 non-null   float64
#  29  BLACK_MARKET                  3109 non-null   float64
#  30  CONTROL_MOVEMENT              3134 non-null   float64
#  31  TRADE                         3035 non-null   float64
#  32  CREDIT_MARKET_REG             3107 non-null   float64
#  33  LABOR_MARKET_REG              2568 non-null   float64
#  34  5c_business_reg               2324 non-null   float64
#  35  REGULATION                    2998 non-null   float64
# dtypes: float64(33), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
economy_df.isnull().sum()
# Out:
# 년도                                 0
# ISO_CODE                           0
# 나라                                 0
# 경제적 자유도                          723
# 순위                               723
# 사분위수                             723
# 정부 지출                            589
# 전송                               960
# 공기업                              646
# 최고 세율                           1047
# 정부 규모                            647
# 사법권 독립도                         1553
# 법원의 공평성                         1179
# 재산권 보호 정도                       1129
# 군사 개입도                          1186
# 청렴한 법 체계성                       1153
# 법적 효력                           1361
# 부동산 매매 제한성                      1384
# 경찰 신뢰도                          2071
# 사업 범죄                           2071
# GENDER_ADJUSTMENT                 66
# PROPERTY_RIGHTS                  755
# MONEY_GROWTH                     644
# STD_INFLATION                    607
# INFLATION                        607
# FOREIGN_CURRENCY                 621
# SOUND_MONEY                      611
# TARIFFS                          681
# 4b_regulatory_trade_barriers    1348
# BLACK_MARKET                     617
# CONTROL_MOVEMENT                 592
# TRADE                            691
# CREDIT_MARKET_REG                619
# LABOR_MARKET_REG                1158
# 5c_business_reg                 1402
# REGULATION                       728
# dtype: int64
