# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.791489  0.383563  0.797193  0.460347
# 1  0.918035  0.797343  0.154410  0.098673
# 2  0.255201  0.342103  0.498868  0.172769
# 3  0.056801  0.243056  0.923506  0.128988
# 4  0.593434  0.801150  0.629259  0.571577

# %%
# grid 생성
df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
# stacked가 기본적으로 true
df.plot.area(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False, grid=True)
# Out:
# <AxesSubplot:>
